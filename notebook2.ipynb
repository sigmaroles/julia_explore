# %% [markdown]
# ## trying to learn Julia from:
# https://youtu.be/DGojI9xcCfg | Working with images in Julia | Week 1 | 18.S191 MIT Fall 2020 | Grant Sanderson

# %%
using Images

# %%
cat1 = load("cat1.png")
# Out:
# 597×1061 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)  RGB{N0f8}(0.0,0.0,0.0)     RGB{N0f8}(0.0,0.0,0.0)
# ...

# %%
typeof(cat1)
# Out:
# Matrix{RGB{N0f8}} (alias for Array{RGB{Normed{UInt8, 8}}, 2})

# %%
aa = cat1[1200:1280]
bb = cat1[1600:1680]
# Out:
# 81-element Array{RGB{N0f8},1} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  ⋮
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)

# %%
RGB{N0f8}(0.9,0.2,0.2)
# note the syntax.. could also do x/255 if that's easier to understand
# the syntax was suggested by the error message itself, first effort was RGB(212,211,233) etc.
# todo: what's the meaning of braces and N0f8 ??
# https://discourse.julialang.org/t/images-and-the-new-color-representation/4793
# Out:
# RGB{N0f8}(0.902,0.2,0.2)

# %%
catWidth, catHeight = size(cat1)
cat1[Int(round(catWidth/2)),Int(round(catHeight/2))]
# Out:
# RGB{N0f8}(0.51,0.443,0.369)
